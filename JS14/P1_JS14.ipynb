# %% [markdown]
# # JS14 - Convolutional Neural Network

# %% [markdown]
# ## Praktikum 1: Klasifikasi Cat vs Dog

# %% [markdown]
# ### Import Library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Pra pengolahan Data

# %% [markdown]
# **Langkah 2.1. Pra Pengolahan Data Training**

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory("E:/kuliah/smt5/machine-learning/dataset/dataset/training_set",
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# **Langkah 2.2. Pra Pengolahan Data Testing**

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory("E:/kuliah/smt5/machine-learning/dataset/dataset/test_set",
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ### Langkah 3 - Pembuatan Model CNN

# %% [markdown]
# **Langkah 3.1.  - Inisiasi Model CNN**

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# **Langkah 3.2. - Pembuatan Layer Konvolusi 1**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# **Langkah 3.3 - Pembuatan Layer Pooling 1**

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2**

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# **Langkah 3.5 - Flattening**

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# **Langkah 3.6 - Fully Connected Layer 1 (Input)**

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# **Langkah 3.7 - Fully Connected Layer 2 (Output)**

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# **Langkah 3.8 - Compile Model CNN**

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Langkah 4 - Fit CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.5691 - loss: 0.6753 - val_accuracy: 0.6560 - val_loss: 0.6142
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 70s 279ms/step - accuracy: 0.6674 - loss: 0.6089 - val_accuracy: 0.6995 - val_loss: 0.5767
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 72s 286ms/step - accuracy: 0.6989 - loss: 0.5731 - val_accuracy: 0.7345 - val_loss: 0.5439
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 66s 264ms/step - accuracy: 0.7316 - loss: 0.5344 - val_accuracy: 0.7445 - val_loss: 0.5328
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 124s 497ms/step - accuracy: 0.7400 - loss: 0.5138 - val_accuracy: 0.7720 - val_loss: 0.4887
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 79s 245ms/step - accuracy: 0.7646 - loss: 0.4858 - val_accuracy: 0.7730 - val_loss: 0.4909
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.7761 - loss: 0.4699 - val_accuracy: 0.7830 - val_loss: 0.4613
# Epoch 8/25
# ...

# %% [markdown]
# ### Langkah 5 - Prediksi dengan 1 Citra

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('E:/kuliah/smt5/machine-learning/dataset/dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step

# %% [markdown]
# Hasilnya menampilkan 1 yang memprediksi bahwa gambar tersebut adalah gambar dog
